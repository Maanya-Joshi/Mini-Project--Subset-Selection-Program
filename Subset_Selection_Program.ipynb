# %% [markdown]
# <a href="https://colab.research.google.com/github/Maanya-Joshi/Mini-Project--Subset-Selection-Program/blob/main/Subset_Selection_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Subset Selection Program:

# %%
import random
S= set([-12,-3,-6,7,2,-2,6,3,9,-7,-5,-8,1,11,-9,-4])
for i in range (0,4368):
  S1=random.sample(S,5)
  if sum(S1)==0:
    print (S1)
# Out:
# [-6, -4, 11, -8, 7]
# [-2, -6, 9, 3, -4]
# [3, 1, 7, -9, -2]
# [-6, -9, 6, -2, 11]
# [-4, -3, 9, 6, -8]
# [-4, 11, -8, 3, -2]
# [7, 1, -6, -4, 2]
# [7, 3, -7, 9, -12]
# [-8, 9, 6, -2, -5]
# [-6, 7, 1, -4, 2]
# [-3, -8, 7, -5, 9]
# [-12, 6, 1, -6, 11]
# [3, 1, -5, 9, -8]
# [7, 11, -6, -9, -3]
# [-2, 3, -5, 11, -7]
# [3, -4, 9, 1, -9]
# [1, 6, -12, 11, -6]
# [-8, -2, 6, 9, -5]
# [-5, 3, -7, 2, 7]
# [7, -8, -6, 9, -2]
# [1, 3, 2, 6, -12]
# [-3, 11, 3, -6, -5]
# [-4, 11, -8, 6, -5]
# [-3, 11, 7, -6, -9]
# [1, -2, -3, 11, -7]
# [6, -8, -5, 11, -4]
# [-2, -9, 2, 3, 6]
# [-7, -6, 9, 1, 3]
# [2, 11, -9, -5, 1]
# [-8, 7, 3, 2, -4]
# [-6, 1, -8, 6, 7]
# [2, 3, -2, 1, -4]
# [7, -5, -7, -4, 9]
# [-2, 1, 2, -8, 7]
# [-2, 2, -4, 1, 3]
# [-9, 7, 9, 1, -8]
# [-8, 1, 9, -5, 3]
# [1, 6, -8, 7, -6]
# [-5, 9, -7, -4, 7]
# [-12, 2, -6, 7, 9]
# [11, -2, -9, 7, -7]
# [-12, 6, -4, 9, 1]
# [3, 9, -9, 2, -5]
# [3, -7, 2, 11, -9]
# [-6, 3, 9, -7, 1]
# [11, 7, -6, -9, -3]
# [3, -6, 9, -12, 6]
# ...
